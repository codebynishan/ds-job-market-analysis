# %% [markdown]
# # importing necessary libaries

# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %% [markdown]
# # importing the csv dataset

# %%
df = pd.read_csv("AI_Job_Market_Trends_2026 .csv")

# %%
df.head()
# Out:
#    job_id                  job_title company_size company_industry    country  \
# 0       1                AI Engineer      Startup           Retail     Canada
# 1       2  Machine Learning Engineer          MNC       Technology  Australia
# 2       3  Machine Learning Engineer          MNC       Technology    Germany
# 3       4           Business Analyst      Startup       Healthcare    Germany
# 4       5             Data Scientist          MNC       Healthcare    Germany
#
#   remote_type experience_level  years_experience education_level  \
# 0      Remote           Senior                 2          Master
# 1      Hybrid              Mid                 0        Bachelor
# 2      Onsite              Mid                14          Master
# 3      Remote              Mid                 9          Master
# 4      Hybrid              Mid                 5          Master
#
#    skills_python  skills_sql  skills_ml  skills_deep_learning  skills_cloud  \
# ...

# %%
df.shape
# Out:
# (10345, 19)

# %%
df.columns.tolist()
# Out:
# ['job_id',
#  'job_title',
#  'company_size',
#  'company_industry',
#  'country',
#  'remote_type',
#  'experience_level',
#  'years_experience',
#  'education_level',
#  'skills_python',
#  'skills_sql',
#  'skills_ml',
#  'skills_deep_learning',
#  'skills_cloud',
#  'salary',
#  'job_posting_month',
#  'job_posting_year',
#  'hiring_urgency',
#  'job_openings']

# %%
df.dtypes
# Out:
# job_id                  int64
# job_title                 str
# company_size              str
# company_industry          str
# country                   str
# remote_type               str
# experience_level          str
# years_experience        int64
# education_level           str
# skills_python           int64
# skills_sql              int64
# skills_ml               int64
# skills_deep_learning    int64
# skills_cloud            int64
# salary                  int64
# job_posting_month       int64
# job_posting_year        int64
# hiring_urgency            str
# job_openings            int64
# dtype: object

# %%
df.describe()
# Out:
#              job_id  years_experience  skills_python    skills_sql  \
# count  10345.000000      10345.000000   10345.000000  10345.000000
# mean    5173.000000          6.950507       0.493088      0.503045
# std     2986.488601          4.320054       0.499976      0.500015
# min        1.000000          0.000000       0.000000      0.000000
# 25%     2587.000000          3.000000       0.000000      0.000000
# 50%     5173.000000          7.000000       0.000000      1.000000
# 75%     7759.000000         11.000000       1.000000      1.000000
# max    10345.000000         14.000000       1.000000      1.000000
#
#           skills_ml  skills_deep_learning  skills_cloud        salary  \
# count  10345.000000          10345.000000  10345.000000   10345.00000
# mean       0.507878              0.498018      0.511455  113438.22726
# std        0.499962              0.500020      0.499893   31389.20106
# min        0.000000              0.000000      0.000000   45083.00000
# ...

# %%
df['job_posting_year'] =pd.to_datetime(df['job_posting_year'])

# %%
df.corr(numeric_only=True)
# Out:
#                         job_id  years_experience  skills_python  skills_sql  \
# job_id                1.000000          0.005175      -0.019155   -0.006148
# years_experience      0.005175          1.000000       0.006734   -0.000512
# skills_python        -0.019155          0.006734       1.000000   -0.004266
# skills_sql           -0.006148         -0.000512      -0.004266    1.000000
# skills_ml            -0.011788         -0.018842      -0.001813    0.008122
# skills_deep_learning -0.003113         -0.010428      -0.005952    0.007081
# skills_cloud         -0.001593          0.000218       0.014725    0.004018
# salary                0.003752         -0.013266       0.009536   -0.003473
# job_posting_month     0.012950         -0.007646       0.013968   -0.002161
# job_openings         -0.016530         -0.018421      -0.005591    0.003133
# experience_level_num  0.003458          0.004658       0.004454   -0.012096
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10345 entries, 0 to 10344
# Data columns (total 20 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   job_id                10345 non-null  int64
#  1   job_title             10345 non-null  str
#  2   company_size          10345 non-null  str
#  3   company_industry      10345 non-null  str
#  4   country               10345 non-null  str
#  5   remote_type           10345 non-null  str
#  6   experience_level      10345 non-null  str
#  7   years_experience      10345 non-null  int64
#  8   education_level       10345 non-null  str
#  9   skills_python         10345 non-null  int64
#  10  skills_sql            10345 non-null  int64
#  11  skills_ml             10345 non-null  int64
#  12  skills_deep_learning  10345 non-null  int64
#  13  skills_cloud          10345 non-null  int64
#  14  salary                10345 non-null  int64
# ...

# %%
df.isnull().sum()
# Out:
# job_id                  0
# job_title               0
# company_size            0
# company_industry        0
# country                 0
# remote_type             0
# experience_level        0
# years_experience        0
# education_level         0
# skills_python           0
# skills_sql              0
# skills_ml               0
# skills_deep_learning    0
# skills_cloud            0
# salary                  0
# job_posting_month       0
# job_posting_year        0
# hiring_urgency          0
# job_openings            0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.groupby('experience_level')['years_experience'].describe()
# Out:
#                    count      mean       std  min  25%  50%   75%   max
# experience_level
# Entry             3513.0  6.949616  4.284716  0.0  3.0  7.0  11.0  14.0
# Mid               3412.0  6.902403  4.381891  0.0  3.0  7.0  11.0  14.0
# Senior            3420.0  6.999415  4.294715  0.0  3.0  7.0  11.0  14.0

# %%
df[(df['years_experience'] == 0) & (df['experience_level'] == 'Senior')]
# Out:
#        job_id                  job_title company_size company_industry  \
# 22         23             Data Scientist      Startup       Technology
# 95         96             Data Scientist       Medium       Technology
# 150       151             Data Scientist       Medium       E-commerce
# 205       206               Data Analyst      Startup           Retail
# 286       287             Data Scientist   Enterprise       Healthcare
# ...       ...                        ...          ...              ...
# 10190   10191              Data Engineer          MNC        Education
# 10243   10244               Data Analyst   Enterprise       Technology
# 10245   10246  Machine Learning Engineer   Enterprise        Education
# 10280   10281           Business Analyst          MNC           Retail
# 10296   10297           Business Analyst      Startup           Retail
#
#          country remote_type experience_level  years_experience  \
# ...

# %%
sns.boxplot(x='experience_level', y='years_experience', data=df)
# Out:
# <Axes: xlabel='experience_level', ylabel='years_experience'>

# %%
mapping = {'Entry':1, 'Mid':2, 'Senior':3}

df['experience_level_num'] = df['experience_level'].map(mapping)

df[['experience_level_num', 'years_experience']].corr()
# Out:
#                       experience_level_num  years_experience
# experience_level_num              1.000000          0.004658
# years_experience                  0.004658          1.000000

# %%
sns.histplot(df["salary"],kde =True)
# Out:
# <Axes: xlabel='salary', ylabel='Count'>

# %%
sns.histplot(df['years_experience'],bins=15)
# Out:
# <Axes: xlabel='years_experience', ylabel='Count'>

# %%
sns.countplot(x='experience_level', data=df)
# Out:
# <Axes: xlabel='experience_level', ylabel='count'>

# %%
sns.countplot(x='education_level', data=df)
# Out:
# <Axes: xlabel='education_level', ylabel='count'>

# %%
sns.countplot(x='remote_type', data=df)
# Out:
# <Axes: xlabel='remote_type', ylabel='count'>

# %%
df['country'].value_counts()
# Out:
# country
# Germany      1498
# Singapore    1490
# Canada       1488
# UK           1485
# India        1470
# USA          1459
# Australia    1455
# Name: count, dtype: int64

# %%
sns.countplot(y='country', data=df, order=df['country'].value_counts().index)
# Out:
# <Axes: xlabel='count', ylabel='country'>

# %%
df['company_industry'].value_counts()
# Out:
# company_industry
# Technology    1787
# E-commerce    1744
# Finance       1724
# Healthcare    1715
# Education     1704
# Retail        1671
# Name: count, dtype: int64

# %%
sns.countplot(x='company_size', data=df)
# Out:
# <Axes: xlabel='company_size', ylabel='count'>

# %%
sns.countplot(x='hiring_urgency', data=df)
# Out:
# <Axes: xlabel='hiring_urgency', ylabel='count'>

# %%
sns.histplot(df['job_openings'],bins=9)
# Out:
# <Axes: xlabel='job_openings', ylabel='Count'>

# %%
df['skills_python'].value_counts()
# Out:
# skills_python
# 0    5244
# 1    5101
# Name: count, dtype: int64

# %%
df['skills_sql'].value_counts()
# Out:
# skills_sql
# 1    5204
# 0    5141
# Name: count, dtype: int64

# %%
df['skills_ml'].value_counts()
# Out:
# skills_ml
# 1    5254
# 0    5091
# Name: count, dtype: int64

# %%
df['skills_deep_learning'].value_counts()
# Out:
# skills_deep_learning
# 0    5193
# 1    5152
# Name: count, dtype: int64

# %%
df['skills_cloud'].value_counts()
# Out:
# skills_cloud
# 1    5291
# 0    5054
# Name: count, dtype: int64

# %%
skills = ['skills_python','skills_sql','skills_ml',
          'skills_deep_learning','skills_cloud']

df[skills].sum().plot(kind='bar')
plt.title('Skill Demand')
# Out:
# Text(0.5, 1.0, 'Skill Demand')

# %%
sns.boxplot(x='experience_level', y='salary', data=df)
# Out:
# <Axes: xlabel='experience_level', ylabel='salary'>

# %%
sns.boxplot(x='education_level', y='salary', data=df)
# Out:
# <Axes: xlabel='education_level', ylabel='salary'>

# %%
sns.boxplot(x='remote_type', y='salary', data=df)
# Out:
# <Axes: xlabel='remote_type', ylabel='salary'>

# %%
sns.boxplot(x='company_size', y='salary', data=df)
# Out:
# <Axes: xlabel='company_size', ylabel='salary'>

# %%
sns.barplot(x='country', y='salary', data=df)
plt.xticks(rotation=45)
# Out:
# ([0, 1, 2, 3, 4, 5, 6],
#  [Text(0, 0, 'Canada'),
#   Text(1, 0, 'Australia'),
#   Text(2, 0, 'Germany'),
#   Text(3, 0, 'UK'),
#   Text(4, 0, 'USA'),
#   Text(5, 0, 'Singapore'),
#   Text(6, 0, 'India')])

# %%
sns.boxplot(x='experience_level', y='years_experience', data=df)
# Out:
# <Axes: xlabel='experience_level', ylabel='years_experience'>

# %%
sns.barplot(x='company_industry', y='salary', data=df)
plt.xticks(rotation=45)
# Out:
# ([0, 1, 2, 3, 4, 5],
#  [Text(0, 0, 'Retail'),
#   Text(1, 0, 'Technology'),
#   Text(2, 0, 'Healthcare'),
#   Text(3, 0, 'Finance'),
#   Text(4, 0, 'Education'),
#   Text(5, 0, 'E-commerce')])

# %%
plt.figure(figsize=(12,8))

sns.heatmap(df.corr(numeric_only=True),
            annot=True,
            cmap='coolwarm')

plt.title('Correlation Heatmap')
# Out:
# Text(0.5, 1.0, 'Correlation Heatmap')

# %%
df['job_posting_month'].value_counts().sort_index().plot(kind='line')
# Out:
# <Axes: xlabel='job_posting_month'>

# %%
df['job_posting_year'].value_counts().sort_index().plot(kind='line')
# Out:
# <Axes: xlabel='job_posting_year'>

# %%
df.groupby('job_title')['salary'].mean().sort_values(ascending=False)
# Out:
# job_title
# AI Engineer                  139945.210677
# Machine Learning Engineer    139705.422989
# Business Analyst             101642.028765
# Data Engineer                 99711.085322
# Data Scientist                99645.837933
# Data Analyst                  99136.475745
# Name: salary, dtype: float64
